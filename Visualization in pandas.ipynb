# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r"C:\Users\somte\Desktop\alex the analyst\pandas\Ice Cream Ratings.csv")
df = df.set_index('Date')

# %%
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
print(plt.style.available) #used in checking available styles for usage i.e colour variation
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use(style= 'seaborn-v0_8-bright') #used in calling the colour/style you want to use

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind = 'line')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind = 'line', subplots = True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
df.plot(kind = 'line', title = 'Ice Cream Ratings', xlabel = 'Daily Ratings', ylabel = 'Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
df.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='Date'>

# %%
df['Flavor Rating'].plot(kind ='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df['Flavor Rating'].plot(kind ='bar', title = 'Flavor Rating', xlabel='Daily Rating', ylabel='Scores')
# Out:
# <Axes: title={'center': 'Flavor Rating'}, xlabel='Daily Rating', ylabel='Scores'>

# %%
df.plot.barh()
# Out:
# <Axes: ylabel='Date'>

# %%
df.plot.barh(stacked = True)
# Out:
# <Axes: ylabel='Date'>

# %%
df.plot.scatter(x = 'Texture Rating', y='Overall Rating')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.scatter(x = 'Texture Rating', y='Overall Rating', s = 150, c= 'red')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.scatter(x = 'Texture Rating', y='Overall Rating', s = 130, c = ['RED', 'YELLOW', 'GREEN', 'BLUE', 'BLACK', 'PURPLE', 'GREY'])
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist(bins = 70) #this bin represents how you want your chart to spread that is how you want your bar, your points to spread on the  chart, it can be 10,20,13,30 any number
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot() #the first dash on the box plot bar is the minimum value, the first part of the box going up is the 25th percentile the green line is the median, the last part of the box is the 75th percentile and the last dash on the bar is the maximum value
# Out:
# <Axes: >

# %%
# using the overall rating box plot as case study, the green line moving away from the middle towards the top shows that it is skewed to the top, that is more of large values that small values, the values are not evenly distributed

# %%
df.plot.area(figsize = (10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.pie(y = 'Flavor Rating')
# Out:
# <Axes: ylabel='Flavor Rating'>

# %%
df.plot.pie(y = 'Flavor Rating', figsize=(10,10))
# Out:
# <Axes: ylabel='Flavor Rating'>
