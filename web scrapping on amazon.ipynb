# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

URL = 'https://www.amazon.com/Apple-iPhone-13-128GB-Midnight/dp/B09LNT1F3H/ref=cs_sr_dp_2?crid=2IN8CGNTKPS77&dib=eyJ2IjoiMSJ9.OL-RPmN_nTE2vB12jaVAyk3p4i7PPg0kQLpjGWUnB7MzW1ub6wYT0o5c-vXcCJdoqT31-MZdZRzy8xqmKjyPi41CavjkCXyA_nthEyTKS-FLoHcHBHiNUCM15c2jSTYhXk8-_TTjelDNrcb_9l4ouyC3MmENrv56m7L4x9Qa2JRFOsx94Bv2j2It4D-ZfuSGv1r6WWKjJ__Do33XT62WCb8lqDlFJQUTusezXxz3DAk.TQ_2Xt0o0Hka7fgLfVGiqfL0zMAxBXaqMv-Bp50XfGM&dib_tag=se&keywords=iphone%2B13&qid=1764621728&sprefix=iphone%2B13%2Caps%2C348&sr=8-1&xpid=ebpFZITz9_s4F&th=1'
page = requests.get(URL, headers = headers)

soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

price_symbol = soup2.find(class_='a-price-symbol').get_text(strip=True)
price_whole = soup2.find(class_='a-price-whole').get_text(strip=True)
price_fraction = soup2.find(class_='a-price-fraction').get_text(strip=True)
price = f'{price_symbol}{price_whole}{price_fraction}'
Name = soup2.find('span', class_='a-size-large product-title-word-break').get_text(strip=True)

print(price + Name)
#print(soup2)
# Out:
# $264.99Apple iPhone 13, 128GB, (PRODUCT)RED - Unlocked (Renewed)

# %%
Name = soup2.find('span', class_='a-size-large product-title-word-break').get_text(strip=True)

print(Name)
# Out:
# Apple iPhone 13, 128GB, (PRODUCT)RED - Unlocked (Renewed)

# %%
price_symbol = soup2.find(class_='a-price-symbol').get_text(strip=True)
price_whole = soup2.find(class_='a-price-whole').get_text(strip=True)
price_fraction = soup2.find(class_='a-price-fraction').get_text(strip=True)
price = f'{price_symbol}{price_whole}{price_fraction}'
print(price)
