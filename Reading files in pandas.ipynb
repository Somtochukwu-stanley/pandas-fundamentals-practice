# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\somte\Desktop\alex the analyst\pandas\countries of the world.csv")
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
pd.read_csv(r"C:\Users\somte\Desktop\alex the analyst\pandas\countries of the world.csv", header = None)
# Out:
#                    0                                    1
# 0            Country                               Region
# 1       Afghanistan         ASIA (EX. NEAR EAST)
# 2           Albania   EASTERN EUROPE
# 3           Algeria   NORTHERN AFRICA
# 4    American Samoa   OCEANIA
# ..               ...                                  ...
# 223       West Bank   NEAR EAST
# 224  Western Sahara   NORTHERN AFRICA
# 225           Yemen   NEAR EAST
# 226          Zambia   SUB-SAHARAN AFRICA
# 227        Zimbabwe   SUB-SAHARAN AFRICA
#
# [228 rows x 2 columns]

# %%
pd.read_csv(r"C:\Users\somte\Desktop\alex the analyst\pandas\countries of the world.csv", header = None, names = ['country', 'region'])
# Out:
#              country                               region
# 0            Country                               Region
# 1       Afghanistan         ASIA (EX. NEAR EAST)
# 2           Albania   EASTERN EUROPE
# 3           Algeria   NORTHERN AFRICA
# 4    American Samoa   OCEANIA
# ..               ...                                  ...
# 223       West Bank   NEAR EAST
# 224  Western Sahara   NORTHERN AFRICA
# 225           Yemen   NEAR EAST
# 226          Zambia   SUB-SAHARAN AFRICA
# 227        Zimbabwe   SUB-SAHARAN AFRICA
#
# [228 rows x 2 columns]

# %%
df = pd.read_csv(r"C:\Users\somte\Desktop\alex the analyst\pandas\countries of the world.csv")
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
df = pd.read_excel(r"C:\Users\somte\Desktop\alex the analyst\Power BI - Final Project.xlsx")
df
# Out:
#                     Unique ID      Email Date Taken (America/New_York)  \
# 0    62a33b3db4da29969c62df3d  anonymous                     6/10/2022
# 1    62a33ba1bae91e4b8b82e35c  anonymous                     6/10/2022
# 2    62a33c2cbc6861bf3176bec1  anonymous                     6/10/2022
# 3    62a33c8624a26260273822f9  anonymous                     6/10/2022
# 4    62a33c91f3072dd892621e03  anonymous                     6/10/2022
# ..                        ...        ...                           ...
# 625  62b525563f28f20328aeee5c  anonymous                     6/23/2022
# 626  62b5a3e29bc428d5345f6e89  anonymous                     6/24/2022
# 627  62b71083f31287f32e189026  anonymous                     6/25/2022
# 628  62b795033b026e423f287ecd  anonymous                     6/25/2022
# 629  62b89039377223ff07b80fb5  anonymous                     6/26/2022
#
#     Time Taken (America/New_York)  Browser  OS  City  Country  Referrer  \
# ...

# %%
pd.read_excel(r"C:\Users\somte\Desktop\alex the analyst\Power BI - Final Project.xlsx", header = None)
# Out:
#                            0          1                              2   \
# 0                   Unique ID      Email  Date Taken (America/New_York)
# 1    62a33b3db4da29969c62df3d  anonymous                      6/10/2022
# 2    62a33ba1bae91e4b8b82e35c  anonymous                      6/10/2022
# 3    62a33c2cbc6861bf3176bec1  anonymous                      6/10/2022
# 4    62a33c8624a26260273822f9  anonymous                      6/10/2022
# ..                        ...        ...                            ...
# 626  62b525563f28f20328aeee5c  anonymous                      6/23/2022
# 627  62b5a3e29bc428d5345f6e89  anonymous                      6/24/2022
# 628  62b71083f31287f32e189026  anonymous                      6/25/2022
# 629  62b795033b026e423f287ecd  anonymous                      6/25/2022
# 630  62b89039377223ff07b80fb5  anonymous                      6/26/2022
#
#                                 3        4    5     6        7         8   \
# ...

# %%
df = pd.read_csv(r"C:\Users\somte\Desktop\alex the analyst\pandas\countries of the world.txt")
df
# Out:
#                                        Country\tRegion
# 0          Afghanistan \tASIA (EX. NEAR EAST)
# 1        Albania \tEASTERN EUROPE
# 2        Algeria \tNORTHERN AFRICA
# 3    American Samoa \tOCEANIA                      ...
# 4        Andorra \tWESTERN EUROPE
# ..                                                 ...
# 222    West Bank \tNEAR EAST
# 223  Western Sahara \tNORTHERN AFRICA              ...
# 224        Yemen \tNEAR EAST
# 225       Zambia \tSUB-SAHARAN AFRICA
# 226     Zimbabwe \tSUB-SAHARAN AFRICA
#
# [227 rows x 1 columns]

# %%
df = pd.read_table(r"C:\Users\somte\Desktop\alex the analyst\pandas\countries of the world.txt")
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
df = pd.read_table(r"C:\Users\somte\Desktop\alex the analyst\pandas\countries of the world.csv", sep = ',')
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
df = pd.read_json(r"C:\Users\somte\Desktop\alex the analyst\pandas\json_sample.json")
df
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
pd.set_option('display.max.columns', 235)

# %%
df = pd.read_json(r"C:\Users\somte\Desktop\alex the analyst\pandas\json_sample.json")
df
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
df = pd.read_excel(r"C:\Users\somte\Desktop\alex the analyst\pandas\world_population_excel_workbook.xlsx")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df = pd.read_excel(r"C:\Users\somte\Desktop\alex the analyst\pandas\world_population_excel_workbook.xlsx", sheet_name = 'Sheet1')
df
# Out:
#      Rank CCA3            Country           Capital
# 0      36  AFG        Afghanistan             Kabul
# 1     138  ALB            Albania            Tirana
# 2      34  DZA            Algeria           Algiers
# 3     213  ASM     American Samoa         Pago Pago
# 4     203  AND            Andorra  Andorra la Vella
# ..    ...  ...                ...               ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu
# 230   172  ESH     Western Sahara         El AaiÃºn
# 231    46  YEM              Yemen             Sanaa
# 232    63  ZMB             Zambia            Lusaka
# 233    74  ZWE           Zimbabwe            Harare
#
# [234 rows x 4 columns]

# %%
pd.set_option('display.max.rows', 235)

# %%
df2 = pd.read_excel(r"C:\Users\somte\Desktop\alex the analyst\pandas\world_population_excel_workbook.xlsx", sheet_name = 'Sheet1')
df2
# Out:
#      Rank CCA3            Country           Capital
# 0      36  AFG        Afghanistan             Kabul
# 1     138  ALB            Albania            Tirana
# 2      34  DZA            Algeria           Algiers
# 3     213  ASM     American Samoa         Pago Pago
# 4     203  AND            Andorra  Andorra la Vella
# ..    ...  ...                ...               ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu
# 230   172  ESH     Western Sahara         El AaiÃºn
# 231    46  YEM              Yemen             Sanaa
# 232    63  ZMB             Zambia            Lusaka
# 233    74  ZWE           Zimbabwe            Harare
#
# [234 rows x 4 columns]

# %%
pd.set_option('display.max.columns', 40)

# %%
df = pd.read_json(r"C:\Users\somte\Desktop\alex the analyst\pandas\json_sample.json")
df
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     234 non-null    int64
#  1   CCA3     234 non-null    object
#  2   Country  234 non-null    object
#  3   Capital  234 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 7.4+ KB

# %%
df2.shape
# Out:
# (234, 4)

# %%
df2.head()
# Out:
#    Rank CCA3         Country           Capital
# 0    36  AFG     Afghanistan             Kabul
# 1   138  ALB         Albania            Tirana
# 2    34  DZA         Algeria           Algiers
# 3   213  ASM  American Samoa         Pago Pago
# 4   203  AND         Andorra  Andorra la Vella

# %%
df2.head(10)
# Out:
#    Rank CCA3              Country           Capital
# 0    36  AFG          Afghanistan             Kabul
# 1   138  ALB              Albania            Tirana
# 2    34  DZA              Algeria           Algiers
# 3   213  ASM       American Samoa         Pago Pago
# 4   203  AND              Andorra  Andorra la Vella
# 5    42  AGO               Angola            Luanda
# 6   224  AIA             Anguilla        The Valley
# 7   201  ATG  Antigua and Barbuda    Saint Johnâ€™s
# 8    33  ARG            Argentina      Buenos Aires
# 9   140  ARM              Armenia           Yerevan

# %%
df2.tail()
# Out:
#      Rank CCA3            Country    Capital
# 229   226  WLF  Wallis and Futuna   Mata-Utu
# 230   172  ESH     Western Sahara  El AaiÃºn
# 231    46  YEM              Yemen      Sanaa
# 232    63  ZMB             Zambia     Lusaka
# 233    74  ZWE           Zimbabwe     Harare

# %%
df2.tail(10)
# Out:
#      Rank CCA3            Country       Capital
# 224    43  UZB         Uzbekistan      Tashkent
# 225   181  VUT            Vanuatu     Port-Vila
# 226   234  VAT       Vatican City  Vatican City
# 227    51  VEN          Venezuela       Caracas
# 228    16  VNM            Vietnam         Hanoi
# 229   226  WLF  Wallis and Futuna      Mata-Utu
# 230   172  ESH     Western Sahara     El AaiÃºn
# 231    46  YEM              Yemen         Sanaa
# 232    63  ZMB             Zambia        Lusaka
# 233    74  ZWE           Zimbabwe        Harare

# %%
df2['Rank']
# Out:
#   Cell In[19], line 1
#     df2['Rank'
#               ^
# _IncompleteInputError: incomplete input

# %%
df2.loc[223]     #loc which means locaton it is used in locating a particular data or row on a datafrome/dataset using the index either the index on X or Y axis whether the index is integer or string, index is usually the very first column on a pandas dataframe of dataset
# Out:
# Rank              133
# CCA3              URY
# Country       Uruguay
# Capital    Montevideo
# Name: 223, dtype: object

# %%
df2.iloc[223]   #iloc works in cases where even if the index changes to another column probably a string, it will still locate it using the integer numbering of the dataframe or dataset, i guess the i stands for integer
# Out:
# Rank              133
# CCA3              URY
# Country       Uruguay
# Capital    Montevideo
# Name: 223, dtype: object
